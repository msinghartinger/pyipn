# %%
from pyipn.io import import_lc
year = 2019

# %%
# GBM Trigdat

import_lc.get_gbm_trigdat_files(year, "/home/msinghart/data/")
# Out:
# 0 of 385
# /home/msinghart/.vevn/pyipn/lib/python3.5/site-packages/pyipn-0.1.0-py3.5.egg/pyipn/io/import_lc.py:161: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 161 of the file /home/msinghart/.vevn/pyipn/lib/python3.5/site-packages/pyipn-0.1.0-py3.5.egg/pyipn/io/import_lc.py. To get rid of this warning, pass the additional argument 'features="html5lib"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(data)
# ...

# %%
import_lc.gbm_trigdat_to_hdf5("/home/msinghart/data/")

# %%
# INTEGRAL SPIACS

import_lc.get_integral_spiacs_files(year,"/home/msinghart/data/")
# Out:
# /home/msinghart/.vevn/pyipn/lib/python3.5/site-packages/pyipn-0.1.0-py3.5.egg/pyipn/io/import_lc.py:288: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 288 of the file /home/msinghart/.vevn/pyipn/lib/python3.5/site-packages/pyipn-0.1.0-py3.5.egg/pyipn/io/import_lc.py. To get rid of this warning, pass the additional argument 'features="html5lib"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(data)
# ...

# %%
import_lc.integral_spiacs_to_hdf5("/home/msinghart/data/")

# %%
# GBM TTE 

import_lc.get_gbm_tte_files(year, "/home/msinghart/data/")
# Out:
# 0 of 386
# /home/msinghart/.vevn/pyipn/lib/python3.5/site-packages/pyipn-0.1.0-py3.5.egg/pyipn/io/import_lc.py:221: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 221 of the file /home/msinghart/.vevn/pyipn/lib/python3.5/site-packages/pyipn-0.1.0-py3.5.egg/pyipn/io/import_lc.py. To get rid of this warning, pass the additional argument 'features="html5lib"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(data)
# ...

# %%
import_lc.gbm_tte_to_hdf5("/home/msinghart/data/")

# %%
# reference position

import_lc.get_reference_grb_position(year, "/home/msinghart/data/")
# Out:
# /home/msinghart/.vevn/pyipn/lib/python3.5/site-packages/pyipn-0.1.0-py3.5.egg/pyipn/io/import_lc.py:345: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 345 of the file /home/msinghart/.vevn/pyipn/lib/python3.5/site-packages/pyipn-0.1.0-py3.5.egg/pyipn/io/import_lc.py. To get rid of this warning, pass the additional argument 'features="html5lib"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(data)
# 2 of 97
# ...
