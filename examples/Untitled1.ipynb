# %%
import numpy as np
import matplotlib.pyplot as plt

a = 0.1
b = 0
c = 0
parab = np.array([a,b,c])
trange = np.arange(-0.5, 0.5, 0.01)
parab_t = np.poly1d(parab)(trange)

    
plt.plot(trange, parab_t)
plt.show()
