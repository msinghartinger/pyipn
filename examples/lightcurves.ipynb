# %%
import matplotlib.pyplot as plt
import numpy as np
import pdb
from astropy.time import Time

from pyipn.io.import_lc import read_integral_spiacs_file, read_gbm_trigdat_file,conv_to_utc_fermi
from pyipn.io.package_utils import get_path_of_data_file, get_path_of_data_dir
import pyipn.cc

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-40d9b6fa3935> in <module>()
# ----> 1 time, count, trigtime = read_INTEGRAL_SPIACS_file("2019-10-23T15-07-10.4996-02120-27536-0.lc")
#
# NameError: name 'read_INTEGRAL_SPIACS_file' is not defined

# %%
print(trigtime.iso)
plt.scatter(time[:300], count[0:300], s=1)
plt.figure(dpi=300)
plt.show()
# Out:
# 2019-10-23 15:07:10.500

# %%
time2, rate, binsize, trigtime2, trigtimesec = read_GBM_TRIGDAT_file("glg_trigdat_all_bn191023630_v01.fit")

# %%
print(trigtime2.iso)

time2 = time2
rate = np.transpose(rate)
rate = np.transpose(rate[np.where((time2-trigtimesec > time[0]) & (time2-trigtimesec < time[300]))])
time22 = time2[np.where((time2-trigtimesec > time[0]) & (time2-trigtimesec < time[300]))]
print(time22)
for r in rate:
    plt.scatter(time22, r, s=2)
    plt.vlines(trigtimeorg, 1300, 2000)
    plt.show()
# Out:
# 2019-10-23 15:07:01.755
# [5.93536018e+08 5.93536019e+08 5.93536020e+08 5.93536021e+08
#  5.93536021e+08 5.93536021e+08 5.93536021e+08 5.93536021e+08
#  5.93536022e+08 5.93536022e+08 5.93536022e+08 5.93536021e+08
#  5.93536021e+08 5.93536022e+08 5.93536022e+08 5.93536022e+08
#  5.93536022e+08 5.93536022e+08 5.93536022e+08 5.93536022e+08
#  5.93536022e+08 5.93536022e+08 5.93536022e+08 5.93536022e+08
#  5.93536023e+08 5.93536022e+08 5.93536023e+08 5.93536023e+08
#  5.93536023e+08 5.93536023e+08 5.93536024e+08 5.93536024e+08
#  5.93536025e+08 5.93536026e+08 5.93536027e+08 5.93536028e+08
#  5.93536029e+08 5.93536030e+08 5.93536031e+08]
